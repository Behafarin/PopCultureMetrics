# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

# Base URL for Rolling Stone's music news
base_url = "https://www.rollingstone.com/music/music-news/page/"

# Function to scrape one page
def scrape_page(page_number):
    url = f"{base_url}{page_number}/"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch page {page_number}: {response.status_code}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    articles = soup.find_all("div", class_="story")
    page_data = []
    for article in articles:
        # Extract title
        title_tag = article.find("h3", class_="c-title")
        title = title_tag.get_text(strip=True) if title_tag else None

        # Extract link
        link_tag = article.find("a", class_="c-title__link")
        link = link_tag["href"] if link_tag else None

        # Extract summary
        summary_tag = article.find("p", class_="c-dek")
        summary = summary_tag.get_text(strip=True) if summary_tag else None

        # Extract category (optional)
        category_tag = article.find("span", class_="c-span")
        category = category_tag.get_text(strip=True) if category_tag else None
        page_data.append({
            "title": title,
            "link": link,
            "summary": summary,
            "category": category
        })

    return page_data

# Function to scrape multiple pages with random sleep
def scrape_multiple_pages(start_page, end_page):
    all_data = []
    for page in range(start_page, end_page + 1):
        print(f"Scraping page {page}...")
        page_data = scrape_page(page)
        if page_data:
            all_data.extend(page_data)
        # Add random sleep to avoid limitations
        sleep_time = random.uniform(1, 5)  # Sleep between 1 to 5 seconds
        print(f"Sleeping for {sleep_time:.2f} seconds...")
        time.sleep(sleep_time)
    return all_data

# Scrape data from pages 1 to 100 (adjust range as needed)
scraped_data = scrape_multiple_pages(1, 100)

# Convert to DataFrame and save as CSV
df = pd.DataFrame(scraped_data)
df.to_csv("rollingstone_music_news1_100.csv", index=False)

print("Scraping complete. Data saved to rollingstone_music_news.csv.")
# Out:
# Scraping page 1...
# Sleeping for 4.18 seconds...
# Scraping page 2...
# Sleeping for 4.22 seconds...
# Scraping page 3...
# Sleeping for 3.03 seconds...
# Scraping page 4...
# Sleeping for 3.81 seconds...
# Scraping page 5...
# Sleeping for 3.63 seconds...
# Scraping page 6...
# Sleeping for 2.33 seconds...
# Scraping page 7...
# Sleeping for 1.34 seconds...
# Scraping page 8...
# Sleeping for 1.54 seconds...
# Scraping page 9...
# Sleeping for 4.46 seconds...
# Scraping page 10...
# Sleeping for 2.88 seconds...
# Scraping page 11...
# Sleeping for 1.07 seconds...
# Scraping page 12...
# Sleeping for 2.52 seconds...
# Scraping page 13...
# Sleeping for 2.36 seconds...
# Scraping page 14...
# Sleeping for 2.06 seconds...
# Scraping page 15...
# Sleeping for 3.42 seconds...
# Scraping page 16...
# Sleeping for 4.08 seconds...
# Scraping page 17...
# Sleeping for 4.14 seconds...
# Scraping page 18...
# Sleeping for 3.70 seconds...
# Scraping page 19...
# Sleeping for 3.35 seconds...
# Scraping page 20...
# Sleeping for 2.91 seconds...
# Scraping page 21...
# Sleeping for 1.45 seconds...
# Scraping page 22...
# Sleeping for 1.58 seconds...
# Scraping page 23...
# Sleeping for 1.98 seconds...
# Scraping page 24...
# Sleeping for 4.54 seconds...
# Scraping page 25...
# Sleeping for 4.00 seconds...
# Scraping page 26...
# Sleeping for 4.56 seconds...
# Scraping page 27...
# Sleeping for 2.23 seconds...
# Scraping page 28...
# Sleeping for 2.49 seconds...
# Scraping page 29...
# Sleeping for 2.53 seconds...
# Scraping page 30...
# Sleeping for 1.37 seconds...
# Scraping page 31...
# Sleeping for 4.67 seconds...
# Scraping page 32...
# Sleeping for 3.23 seconds...
# Scraping page 33...
# Sleeping for 2.18 seconds...
# Scraping page 34...
# Sleeping for 4.31 seconds...
# Scraping page 35...
# Sleeping for 3.44 seconds...
# Scraping page 36...
# Sleeping for 4.99 seconds...
# Scraping page 37...
# Sleeping for 4.16 seconds...
# Scraping page 38...
# Sleeping for 3.01 seconds...
# Scraping page 39...
# Sleeping for 3.35 seconds...
# Scraping page 40...
# Sleeping for 2.00 seconds...
# Scraping page 41...
# Sleeping for 3.45 seconds...
# Scraping page 42...
# Sleeping for 4.75 seconds...
# Scraping page 43...
# Sleeping for 4.01 seconds...
# Scraping page 44...
# Sleeping for 3.36 seconds...
# Scraping page 45...
# Sleeping for 1.76 seconds...
# Scraping page 46...
# Sleeping for 1.11 seconds...
# Scraping page 47...
# Sleeping for 4.04 seconds...
# Scraping page 48...
# Sleeping for 1.92 seconds...
# Scraping page 49...
# Sleeping for 3.16 seconds...
# Scraping page 50...
# Sleeping for 4.61 seconds...
# Scraping page 51...
# Sleeping for 4.56 seconds...
# Scraping page 52...
# Sleeping for 4.34 seconds...
# Scraping page 53...
# Sleeping for 3.83 seconds...
# Scraping page 54...
# Sleeping for 1.23 seconds...
# Scraping page 55...
# Sleeping for 2.36 seconds...
# Scraping page 56...
# Sleeping for 3.06 seconds...
# Scraping page 57...
# Sleeping for 1.46 seconds...
# Scraping page 58...
# Sleeping for 2.92 seconds...
# Scraping page 59...
# Sleeping for 4.67 seconds...
# Scraping page 60...
# Sleeping for 3.37 seconds...
# Scraping page 61...
# Sleeping for 3.17 seconds...
# Scraping page 62...
# Sleeping for 4.03 seconds...
# Scraping page 63...
# Sleeping for 3.28 seconds...
# Scraping page 64...
# Sleeping for 4.02 seconds...
# Scraping page 65...
# Sleeping for 4.07 seconds...
# Scraping page 66...
# Sleeping for 4.65 seconds...
# Scraping page 67...
# Sleeping for 2.56 seconds...
# Scraping page 68...
# Sleeping for 2.28 seconds...
# Scraping page 69...
# Sleeping for 4.83 seconds...
# Scraping page 70...
# Sleeping for 4.63 seconds...
# Scraping page 71...
# Sleeping for 3.63 seconds...
# Scraping page 72...
# Sleeping for 2.14 seconds...
# Scraping page 73...
# Sleeping for 4.23 seconds...
# Scraping page 74...
# Sleeping for 4.37 seconds...
# Scraping page 75...
# Sleeping for 2.99 seconds...
# Scraping page 76...
# Sleeping for 2.49 seconds...
# Scraping page 77...
# Sleeping for 4.90 seconds...
# Scraping page 78...
# Sleeping for 4.21 seconds...
# Scraping page 79...
# Sleeping for 4.18 seconds...
# Scraping page 80...
# Sleeping for 4.95 seconds...
# Scraping page 81...
# Sleeping for 2.36 seconds...
# Scraping page 82...
# Sleeping for 4.11 seconds...
# Scraping page 83...
# Sleeping for 2.67 seconds...
# Scraping page 84...
# Sleeping for 4.93 seconds...
# Scraping page 85...
# Sleeping for 4.41 seconds...
# Scraping page 86...
# Sleeping for 2.40 seconds...
# Scraping page 87...
# Sleeping for 4.73 seconds...
# Scraping page 88...
# Sleeping for 2.66 seconds...
# Scraping page 89...
# Sleeping for 1.95 seconds...
# Scraping page 90...
# Sleeping for 4.01 seconds...
# Scraping page 91...
# Sleeping for 3.74 seconds...
# Scraping page 92...
# Sleeping for 2.91 seconds...
# Scraping page 93...
# Sleeping for 3.74 seconds...
# Scraping page 94...
# Sleeping for 2.77 seconds...
# Scraping page 95...
# Sleeping for 2.33 seconds...
# Scraping page 96...
# Sleeping for 4.87 seconds...
# Scraping page 97...
# Sleeping for 4.74 seconds...
# Scraping page 98...
# Sleeping for 1.98 seconds...
# Scraping page 99...
# Sleeping for 4.01 seconds...
# Scraping page 100...
# Sleeping for 1.86 seconds...
# Scraping complete. Data saved to rollingstone_music_news.csv.

# %%
df
# Out:
#                                                 title  \
# 0   Azealia Banks Demands Apology and $1 Million F...
# 1   Liam Payne’s Girlfriend Kate Cassidy Shares Jo...
# 2   Jay-Z Fights Back Against 13-Year-Old Rape Acc...
# 3   Kathleen Hanna, Tegan and Sara, More Back Inte...
# 4   Ariana Grande, Selena Gomez, Miley Cyrus Score...
# 5   How Lady Gaga Embraced ‘Exercises in Chaos’ to...
# 6   Taylor Swift’s Eras Tour Earned History-Making...
# 7   Azealia Banks Demands Apology and $1 Million F...
# 8   Liam Payne's Girlfriend Kate Cassidy Shares Jo...
# 9   Jay-Z Fights Back Against 13-Year-Old Rape Acc...
# 10  Kathleen Hanna, Tegan and Sara, More Back Inte...
# 11  Ariana Grande, Selena Gomez, Miley Cyrus Score...
# 12  How Lady Gaga Embraced ‘Exercises in Chaos’ to...
# 13  Taylor Swift's Eras Tour Earned History-Making...
# 14  ‘Wicked,' 'The Bear,’ and 'Emelia Pérez' Domin...
# 15  Watch Joe Biden Celebrate Grateful Dead at 47t...
# 16  Watch Taylor Swift's Final Surprise Song Perfo...
#
#                                                  link  \
# 0   https://www.rollingstone.com/music/music-news/...
# 1   https://www.rollingstone.com/music/music-news/...
# 2   https://www.rollingstone.com/music/music-news/...
# 3   https://www.rollingstone.com/music/music-news/...
# 4   https://www.rollingstone.com/music/music-news/...
# 5   https://www.rollingstone.com/music/music-news/...
# 6   https://www.rollingstone.com/music/music-news/...
# 7   https://www.rollingstone.com/music/music-news/...
# 8   https://www.rollingstone.com/music/music-news/...
# 9   https://www.rollingstone.com/music/music-news/...
# 10  https://www.rollingstone.com/music/music-news/...
# 11  https://www.rollingstone.com/music/music-news/...
# 12  https://www.rollingstone.com/music/music-news/...
# 13  https://www.rollingstone.com/music/music-news/...
# 14  https://www.rollingstone.com/music/music-news/...
# 15  https://www.rollingstone.com/music/music-news/...
# 16  https://www.rollingstone.com/music/music-news/...
#
#                                               summary              category
# 0   Last week, Banks said she would be taking lega...                  None
# 1   Cassidy previously paid homage to Payne in an ...                  None
# 2   After issuing a lengthy statement on Sunday de...                  None
# 3   Over 300 artists signed Fight for the Future's...                  None
# 4   Grande and Gomez are nominated for Best Perfor...                  None
# 5                                                None         The Breakdown
# 6                                                None      Two for the Show
# 7   Last week, Banks said she would be taking lega...     Legal Development
# 8   Cassidy previously paid homage to Payne in an ...             In Memory
# 9   After issuing a lengthy statement on Sunday de...      COURTS AND CRIME
# 10  Over 300 artists signed Fight for the Future's...           78 Squabble
# 11  Grande and Gomez are nominated for Best Perfor...  Big Screen Pop Stars
# 12  Gaga dissects the lead single off her upcoming...         The Breakdown
# 13  More than 10 million people attended the Eras ...      Two for the Show
# 14  The BrutalistandThe Substancealso scored multi...    Golden Globes 2025
# 15  The ceremony also honored Bonnie Raitt, Franci...           Legacy Acts
# 16  The singer played five songs, including "Long ...     So Long, Farewell
