# %%
import pandas as pd
import spacy
from spacy.cli import download

# %%
# You can skip these and read files locally
from google.colab import drive
drive.mount('/content/drive')

# %%
# Either read files locally or build your own directory on google drive
news_path = "/content/drive/MyDrive/<Your Directory!>/news data"
file_name = "/rollingstone_music_news"
news = pd.DataFrame()
for i in range(0,1000,100):
    tmp_df = pd.read_csv(news_path+file_name+str(i)+"_"+str(i+100)+".csv")
    news = pd.concat([news, tmp_df])

# %%
download("en_core_web_sm")
nlp = spacy.load("en_core_web_sm")

# Combine title and summary for better context
def extract_person_names(text):
    """
    Extract PERSON entities (full names) from the text using spaCy's NER.
    """
    if pd.isnull(text):  # Handle missing values
        return []

    doc = nlp(text)
    person_names = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
    return person_names

# Apply NER on the title and summary fields
news['extracted_names_title'] = news['title'].apply(extract_person_names)
news['extracted_names_summary'] = news['summary'].apply(extract_person_names)

# Combine and deduplicate extracted names for each row
news['extracted_names'] = news.apply(
    lambda row: list(set(row['extracted_names_title'] + row['extracted_names_summary'])),
    axis=1
)

# Create a flat list of all unique names across the dataset
all_unique_names = set(name for names_list in news['extracted_names'] for name in names_list)
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# Adjust your path
news.to_csv("/content/drive/My Drive/<Your Directory!>/rollingstone_news.csv", index=False)

# %%
# Adjust your path
drive_path = '/content/drive/My Drive/<Your Directory!>/extracted_names.txt'
# Save the file to Google Drive
with open(drive_path, "w") as f:
    for name in all_unique_names:
        f.write(name + "\n")

print(f"File saved to {drive_path}")

# %%
all_unique_names
# Out:
# {'BBC Concert',
#  'Eva Apio',
#  'Daughter Excluded From',
#  'Kelis',
#  'Kid Cudi',
#  "Sheryl Crow's",
#  'Jagari',
#  'Fetty Wap Pleads Guilty',
#  'Becky G Cries',
#  'Arena Tour',
#  'Ian Bairnson',
#  'Betty',
#  'Rapper Said',
#  'Ally Brooke',
#  "Bonnie Raitt Showcase New LP '",
#  'Jamie xx',
#  'Vevo',
#  'Found Dead',
#  'Taemin',
#  'Molly Shannon',
#  'Tom Morello',
#  'Kurtis Blow',
#  'Depeche Mode Showcase',
#  'Crow',
#  'Zach Bryan Returns',
#  'Cissy Houston',
#  'Jimmy Iovine Accuser Drops Sexual Abuse Lawsuit',
#  'Jarre',
#  'Chester Bennington’s',
#  'Recover R. Kelly',
#  'Taylor Swift Superfan',
#  'Olivia Rodrigo',
#  'Bruce Springsteen Joins',
#  "Sweet Ballad '",
#  'Rap Lyrics',
#  'Doc McGhee',
#  'Lorde',
#  'Jeff Landry',
#  'Rihanna Soundtracks ‘',
#  "Deryck Whibley's",
#  'Joan Jett',
#  'Spencer Sutherland',
#  'Cardi B Appears',
#  'P. Diddy',
#  'Tierra Whack',
#  'Don Henley’s',
#  'Foster Hudson',
#  'Robert Kelly',
#  'AP',
#  'Drew Dixon',
#  "D'Angelo Join Audible's",
#  'Frontman James Hetfield',
#  'Lizzo Is Always ‘Chasing',
#  'Moon',
#  'Seymour Stein',
#  'Jo Koy',
#  'Reese Witherspoon',
#  'Galen Johnson',
#  'Flashbacks',
#  'Messi Listens',
#  'Michael Stipe Assures',
#  'Face Him',
#  'John Legend Boosts',
#  'Cassandra',
#  'Cabello',
#  'Renee Rapp Sings',
#  'Stewart Copeland',
#  'Jin Gives',
#  'Kesha Re-Credited',
#  'Madison Beer Returns',
#  'Tobias Jesso Jr.',
#  'Yo La Tengo Deliver Ode',
#  'Smokey Robinson Shares',
#  'Jo Mersa Marley',
#  "Emo Jimmy'",
#  'Purple Teeth',
#  'Fantasy',
#  'Dave Grohl Put',
#  'Mini',
#  'Gracie Abrams Drops',
#  'Faralbum',
#  'Inches Closer',
#  "the Chili Peppers'",
#  'Gary',
#  'Sophie Allison',
#  'Andrew VanWyngarden',
#  'Trayvon Newsome',
#  'Jennie Hits',
#  'Sharpe',
#  'Takes Down',
#  'David Lynch',
#  "Steve Lacy's",
#  'Weyes Blood',
#  'Alice Cooper Is',
#  'John Lennon Singing ‘Yellow Submarine',
#  'Mac Miller Estate',
#  'Bitter Heartbreak',
#  'Beyoncé Endorses Kamala Harris',
#  'Taylor Swift Celebrates Simone Biles',
#  'Takeoff Take',
#  'Gene Simmons',
#  'Adam Sandler',
#  'Summer Vacationhit',
#  'Bowser',
#  "George 'Funky' Brown",
#  'Prize Concert',
#  'Forcing Poison',
#  'Clairo Takes',
#  'Beyoncé Will Join',
#  'Rhiannon Giddens',
#  'Chris Martin Deepfaked',
#  'Heartfelt Piano',
#  "Kelly Clarkson's",
#  'Death Cab for Cutie',
#  'Debbie Harry',
#  'Lizzo Drops',
#  'Kelly Clarkson Takes Miley',
#  "Olivia Rodrigo Is '",
#  'Ed Sheeran Reacts',
#  'Fate',
#  'Kanye West Paid Settlement',
#  'Nigel Lythgoe',
#  'Preview Long-Awaited',
#  "Skinny Love'",
#  "Joe Trohman '",
#  'Thin Lizzy',
#  'Shakey Graves',
#  "Billy Joel's",
#  'Matt McJunkin',
#  "Shakira Unveils '",
#  'Sweet Mirage',
#  'Afterparty',
#  'Larry Carlton',
#  'Emmanuel Macron',
#  'Sivan',
#  'Adam Lambert Offers Refuge From ‘',
#  'Camila Cabello Joins Stromae',
#  "Chris Martin's",
#  'Jazmine Sullivan',
#  'Adrian Brody Joins Rauw Alejandro',
#  "Xtina Ballad '",
#  'Frat King Will Ferrell',
#  'Ryman',
#  'Nardo Wick',
#  "Ian Curtis'",
#  'Journey',
#  'Lil Baby',
#  'Kick Ass',
#  'Malcolm',
#  'Martin Shkreli',
#  "Nancy Sinatra's",
#  'Jessica Pratt Drops',
#  'Les McCann',
#  'Dickinson',
#  'Jackie Wilson',
#  'Glinda',
#  'Mignonette',
#  "Emmy Russell Seeks '",
#  'Jennifer McBride',
#  'Diplo Sued for',
#  'Will Celebrate',
#  "Nonsense Karaoke'",
#  'Sing Along',
#  'Bassnectar Seeks',
#  'Hallmark Hit With',
#  'Schoolboy Q',
#  'Jay Trial',
#  'Chromatica Ballfilm',
#  'Perform Prince Tribute',
#  "Gloria Gaynor's",
#  'Lumineers',
#  "Dre-Assisted Single '",
#  'Moi Showcases Groove-Laden Track',
#  "Perfect Friend'",
#  'Megadeth Push Back',
#  'Colin Burgess',
#  'Arianna Davis',
#  'Slows Down',
#  'Helen Mirren',
#  'Melissa Auf',
#  'Keke Palmer',
#  'theMidnightstrack',
#  'Angela Yee',
#  'Weyes Blood Embrace',
#  'Felt',
#  'John Summit Reflects',
#  'Margaret Cho',
#  'Penn Badgley',
#  'leg kicks',
#  'Gordon Lightfoot Song',
#  "Kelly Clarkson Prove '",
#  'Dirt',
#  'Chris Maas',
#  "Alicia Keys Performs Gorgeous '",
#  'Harry Styles Grammys',
#  'Yoakam',
#  'Jennifer Lopez Files',
#  'Madi Diaz',
#  'Summer Carnival',
#  'Perfume Genius',
#  'Lily Gladstone',
#  'Michael Anthony',
#  'Travis Scott Extends',
#  'Trey',
#  'Lizzo Duet',
#  'Wala Shot Dead',
#  'Joey King',
#  'Sweet Honey',
#  'Rescinds Ban',
#  'Gloria Trevi Sex Cult Claims Revived',
#  'Dave Grohl Roar',
#  'Barack Obama Inspire',
#  'Accuser Melissa Schuman',
#  'Omar',
#  'Winner',
#  'Cameo',
#  'Brian Warner',
#  'Rusk',
#  'Maya Hawke Details',
#  'Osbourne',
#  'Taylor Swift Changes ‘Karma’ Lyric',
#  "Tanya Donelly's",
#  "Rob Schneider's",
#  'Bully Plots Tour',
#  'Revs Up',
#  'Young Thug Released',
#  "Ken Sings '",
#  'H.E.R. Perform',
#  'Lee Harvey Oswald',
#  'Lucy Dacus-Led',
#  "Dua Lipa Is Bringing '",
#  "Chaka Zulu '",
#  'Hudson',
#  'Billy Crystal',
#  "Jeff Tweedy's",
#  'Maggie Rogers Gives',
#  'Elvis Presley Hologram',
#  'Chanté Moore',
#  'Nemah Hasan',
#  'Jimmy Eat World’sBleed American',
#  "Perform Disco-Infused Single '",
#  'Underwood Songwriter',
#  'Brad Paisley',
#  'Roy Haynes',
#  'Moses Sumney',
#  'Anuel AA',
#  'Accuser Blasts Singer',
#  'Fuzzy Haskins',
#  'Frank Marshall',
#  'Hannah Spearritt',
#  'Jimmy Cooks',
#  'John Cameron Mitchell',
#  "Lenny Kravitz Schedules '",
#  'Lizzy',
#  'Oasis',
#  'David Byrne',
#  'Rihanna',
#  "Sleater-Kinney Preview '",
#  'Mommy Grieves',
#  'Tour North America',
#  'Jay',
#  "FKA Twigs Showcases '",
#  'Phillip Boykin',
#  'Donovan Thomas',
#  'Lady Gaga Embraced ‘Exercises',
#  'Meghan]',
#  'Fentanyl',
#  'MoFi',
#  'Anyma',
#  'Cody Jinks',
#  'Kendrick Lamar Dominates',
#  'Childish Gambino Falls',
#  'Kim Petras Brings',
#  'Yung Miami',
#  'Dijon',
#  'Aaron Dessner',
#  'Goblin Co-Founder',
#  "Jimi Hendrix's",
#  'Tesla',
#  'Shakura L. Ingram',
#  'Carey Searches',
#  'Martell',
#  'Ghostface Killah',
#  'Perform Tom Petty',
#  'Lizzo Served',
#  "Any Time Soon'",
#  'Eli Janney',
#  'Róisín Murphy',
#  'Feet High',
#  'Drag Stars Sugar',
#  'Joshua Bassett Shuts',
#  "Camila Cabello Drops Long-Teased Single 'I Luv It'",
#  'Danger Mouse Release',
#  'Michelle Branch Arrested',
#  'Lizzo Dancer Lawsuit',
#  'Overcame Laryngitis',
#  'Madison Beer Offers',
#  "Bruce Springsteen's",
#  'Ciara Taps Busta Rhymes',
#  'Miguel Conjure',
#  'CoCo Lee',
#  "Janelle Monáe's '",
#  'Marisa Abela',
#  'Niko Rubio Finds',
#  'Cardi B Files',
#  'Korn Sold',
#  "Snow Angel'",
#  'Kylie Minogue',
#  "mark drummer's",
#  'Heartbreakers',
#  'Spoofed Him',
#  'Concert Due',
#  'Flav Sing',
#  'R. Kelly Ordered',
#  'Bad Bunny Lizzo',
#  'Angel Olsen Covers',
#  'Donald Glover',
#  'Amar De Nuevo',
#  'Reginae Carter',
#  'Jesus Is King',
#  'Taylor Swift Delivers',
#  'Simon LeBon',
#  "Incredibly Difficult' Separation",
#  'Julien Baker Previews New Songs',
#  'Khalid Comes Out',
#  'Murph',
#  'Kylie',
#  'Bratmobile Set Off',
#  "Rauw Alejandro's",
#  'Anthem Kick Out',
#  "Katy Perry Flies Through '",
#  'Martin Scorsese',
#  'Aaron',
#  'Garrison Burgess',
#  'Taylor Swift Breakup',
#  'Clark Sisters',
#  'Eric Clapton Drummer Convicted',
#  "Travis Scott Brings '",
#  'KP6',
#  'Roses Sue Weapons Dealer',
#  'Brian Eno Brings',
#  'Noel Gallagher',
#  "Aretha Franklin's",
#  'Loves Madonna',
#  'Warns',
#  'Gary Young',
#  "Paul McCartney '",
#  'Kim Petras‘ ’',
#  'Halsey Sings',
#  'Taylor Swift-Inspired Friendship Bracelets',
#  'Young Miko',
#  'John Oates Fights That ‘Disconnected’ Feeling',
#  'Geordie Greep',
#  "Shut Up'",
#  'Christina Perri Yearns for Familiarity',
#  'Sean Combs Demands Dismissal',
#  'Agatha Christie',
#  'Seyi Sodimu’s',
#  'Courtney Love Joins',
#  'Stray Kids Get Sticky',
#  'Charles Esten',
#  'Tyrone Davis',
#  'Rachel Chinouriri Drops',
#  "Ed Sheeran '",
#  'Ferg Champions ‘Honesty',
#  'Moose',
#  'Jazzy LA3C Festival',
#  'Lena Dunham',
#  'Mejean Barriere',
#  'Sebastian Cancel Tour',
#  'Pete Agnew',
#  'Bowie',
#  'Kim Petras',
#  'Salute Veterans',
#  "Paul Oakenfold Denies '",
#  'Ashlee Simpson Got ‘Butterflies’ Playing Music For Her Mother-in-Law',
#  'Allan Mayes',
#  'Billy Corgan Enters Charity Raffle',
#  'Momma',
#  'Concert Return',
#  'Bon Iver Announce',
#  'Taylor Swift Told Lana Del Rey',
#  'Stiffed',
#  'Colin Kenrick',
#  'Kanye West Fallout Sparks',
#  'Chaka Khan',
#  'Seeks Dismissal',
#  'Kate Capshaw',
#  'Westside Boogie’s Life',
#  'Saltburn',
#  'Rashida Tlaib',
#  'Ortega',
#  "Nicki Minaj's '",
#  'Stoneabout',
#  'Studio',
#  'Amapiano',
#  'Billy Porter',
#  'Carla Bley',
#  "Chappell Roan's",
#  'Jamaal Bowman',
#  'Vulgar',
#  'Eilish',
#  'Skete Davidson',
#  'Taylor Swift Distraught',
#  'Ronald Reagan',
#  'Tour Concert Film',
#  'Cassandra Hatton',
#  'Homie Quan',
#  'Dom Dolla',
#  'Bettye LaVette',
#  'Robert',
#  'Leonard Cohen Cover',
#  'Jacksonwill',
#  "Lil Uzi Vert's",
#  'Taylor Swift-Themed Dance Class Stabbing Faces',
#  "Killer Mike's",
#  'Zeppelin',
#  "Taylor Swift Just Released '",
#  'Lorde Revives Unreleased ‘Melodrama',
#  'Daniel Pemberton',
#  'George Dickel Bourbon',
#  'Beyoncé Song',
#  'Kanye Appears',
#  'Kylie Minogue Amps',
#  "Michael Rapino's",
#  'Sing Miley Cyrus',
#  'Gorillaz Drop',
#  'Alex Gibney',
#  'Luke Collab',
#  "Mona Lisa'",
#  'Jesus Was',
#  'Young Thug Sued',
#  'Grohl',
#  'James Skoufis',
#  "Jennifer Hudson Perform Impromptu '",
#  'Drummer Stephen Morris',
#  'Lennon',
#  'Cynthia Erivo Perform Half',
#  "Megan Thee Stallion '",
#  'OnCall',
#  'Exuberant Speech',
#  'Sean Kelly',
#  'Alesha Dixon',
#  "Corey Taylor's",
#  'Taylor Swift Debut ‘',
#  'Tito Jackson',
#  'Fleet Foxes',
#  'Cardi B Is Done With',
#  'Pat McCrory',
#  'a Clown Emoji',
#  'Alix Earle',
#  'Jake Wesley',
#  'Craig Mims',
#  'Sylvia',
#  'Zara Larsson Celebrates Release',
#  'Ryan Gosling',
#  "Tony Iommi's",
#  'Jane Lynch',
#  'Backdrop',
#  "Elizabeth II's",
#  "Elvis Presley's '",
#  'albumHarry',
#  'Park Heong-joon',
#  'Mike Campbell Will Reunite',
#  'Elyanna',
#  'Fahrenheit-182',
#  'Andy Taylor',
#  'David Lee Roth',
#  'Budokan',
#  'Kiernan ‘AKA',
#  'Plans Concert Film',
#  'Asghari',
#  "Lizzo Ditches 'Truth Hurts'",
#  'Andra Day Takes',
#  'Sabrina Carpenter Serves',
#  'Bad Brains Cover',
#  'Celine Dion',
#  'Kali Uchis',
#  'Jamie',
#  'Americaco',
#  "Brenda Lee's",
#  'Zombies',
#  'Eric Andre',
#  "Hayley Williams Duet '",
#  'Cuco Enlists Bratty',
#  'Sigur Rós Announce',
#  'Jessie',
#  'Margaret Sohn',
#  'Jung Kook Taps',
#  'Jerry Garcia',
#  'Bruce Jackson',
#  'Zakk Wylde',
#  "Bowen Yang's '",
#  "Waxahatchee Brings '",
#  'Gov Ball Performance',
#  'Ellie Goulding',
#  'Jung Kook Delivers',
#  'Kacey Musgraves',
#  'Ronnie',
#  'Pete Brown',
#  'Axel F',
#  'Taylor Swift Invites Fans',
#  'Death Cab for Cutie Taps Lance Bangs',
#  "Jon Batiste's",
#  "Meryl Streep-Sung Ballad '",
#  'John Slattery',
#  'Mark 100th Episode',
#  "Melle Mel Talk Hip-Hop's Roots",
#  'Angelina Jolie',
#  'Ghana Afrobeats',
#  'Bob Dylan Superfans Join Forces',
#  'John Legend Is',
#  'Jane Doe Drops',
#  'Aespa',
#  'Christine McVie Estate',
#  "Ed Sheeran Releases Special '",
#  'Pete Davidson Is Out',
#  'Tim Burgess',
#  'Madonna Performs With',
#  'Jerry Leiber',
#  'Billie Joe Armstrong',
#  'Hombres G',
#  'Steve',
#  'Liam',
#  'Feels Good',
#  'Billy Joel',
#  'Anita Pallenberg',
#  'Alex Ross Perry',
#  "Meek Mill Bring '",
#  'Alice Coltrane',
#  'Zara',
#  'Xena',
#  "Share Track '",
#  'Mac McCaughan',
#  "John Squire Bring '",
#  'Adele Opens Up',
#  "Taylor Nation's",
#  'Carlisa Brown',
#  'Caserta',
#  "Roger Daltrey's",
#  'Daryl Hall',
#  'App Parler',
#  "Phil Sgrosso's",
#  'Sting Perform',
#  'Martin Luther King Jr.',
#  'Desus',
#  'David Attenborough',
#  "Denies Taylor Swift's",
#  'Travis Scott Plots Show',
#  'Teddy Swims',
#  'Fetty Wap Sentenced',
#  'Willie Nelson Remembers',
#  'Katy Kirby',
#  'Taraji P. Henson',
#  'George Winston',
#  "Taylor Swift Will Get Extra 'Karma' Points With Ice Spice Remix",
#  'Spaghettii',
#  "Taylor Swift's ‘Eras’",
#  'Sleater-Kinney',
#  'Taylor Swift Announces',
#  'William "Poogie" Hart',
#  'Chris Martin Sing',
#  'J. Cole Responds',
#  'PJ Harvey',
#  'Stairs',
#  'Kirk Franklin',
#  'LeBron James',
#  'Perform Double Duty',
#  'Katy Perry ‘',
#  "Jack Antonoff's '",
#  'Glitch Along',
#  "Alex Ross Perry's",
#  'Porn',
#  'Travis Kelce Declares ‘',
#  'Neil',
#  'Nicki Minaj Is Hella',
#  'Rauw Alejandro Drop',
#  'Elon Musk',
#  'Luke Settle',
#  'John Mayer',
#  'Mark Needham',
#  "Neal Francis's",
#  'Amelia',
#  'Sues Ex-Husband',
#  'Mitski Searches',
#  'Megan',
#  'Noah Kahan Close',
#  "Robert Pollard's",
#  "Ice Spice '",
#  'Greece Concert',
#  'Wayne',
#  'Perry Farrell',
#  'Latto Get',
#  "Divine Mascis'",
#  'Turnstile',
#  'Drill Track',
#  "Lil Peep's",
#  "Kelsea Ballerini's",
#  "Have Taylor Swift's",
#  'Austin',
#  'Mamushi',
#  'Bernie Taupin',
#  'Beyoncé Continues Honoring',
#  'Denies Dismissal',
#  'Becky G Celebrates Mexican-American Heritage',
#  'K.L',
#  'Taylor Swift Got Ticketmaster',
#  'Mule',
#  'Frank Turner',
#  'Jamie Scott',
#  'Jeremy Dufrene',
#  'Those Long-Awaited Visuals',
#  'Lenny Kravitz Perform',
#  'Lauren Pazienza',
#  'Desk Concert',
#  'Andrea Bocelli',
#  'Lenny Kravitz Update',
#  'Ed Stasium',
#  'Bonnie McKee Drops',
#  'Jhpiego',
#  'Saena',
#  'Riot Tell Putin',
#  'Lizzo Day Drinks',
#  "Donna Summer's '",
#  'Janet Zuccarini',
#  "Lil Wayne Reveal '",
#  'Taylor Swift Dreams',
#  "Shaboozey for Beating Two '",
#  'Chateau Ste',
#  'Zach Bryan Apologizes',
#  'Este Haim',
#  'Aaron Donald',
#  'Read R. Kelly',
#  'Lindsay Lohan Releases ‘Jingle Bell',
#  "Bob Dylan '",
#  'Tour Coming',
#  "Kidz Bop'",
#  'Jackson Wang',
#  'Luther Vandross',
#  'Rob Schneider',
#  'Shakira Reveals',
#  "a Spanglish Remix of Hit 'Players'",
#  'Cover Art Calls',
#  'Writers Strike',
#  'Spelman Homecoming',
#  'DaBaby Accused',
#  'Tipsy',
#  'Noah Kahan',
#  'Loretta Lynn',
#  'Bad Bunny Catches a Ride',
#  'Diageo Amid',
#  'Chief Keef',
#  "Sharon Van Etten's",
#  'Doug Ingle',
#  "Rapper Coolio's",
#  'Harry Styles Wrote',
#  'Katy Perry Opens',
#  'Headline Lollapalooza',
#  "Olivia Rodrigo '",
#  'License Suspended',
#  'Hayley Williams Reflects',
#  'Frankie Valli',
#  'Found',
#  'Aaron Carter’s',
#  'Lil Nas X Lead',
#  'John Stamos',
#  'Jon Boni',
#  'Harry Nilsson',
#  'Wood',
#  'Hayley Williams Slams',
#  'Harry Styles Wins',
#  'Start Herewill',
#  "Taylor Swift Told Him '",
#  'Cover Art',
#  'Mike Moz',
#  'Jack White',
#  'Sarah Kinsley',
#  'Taylor Swift Song',
#  'Al Greenwood Reunite',
#  'Matt Berninger',
#  'Eydie',
#  'Death Cab for Cutie Point',
#  'Rap Trap',
#  'James Taylor Apologizes',
#  "Fifth Harmony's",
#  'Fellow MAGA-head',
#  'Spike Jonze',
#  'Lauren Mayberry Pulls Back',
#  'L. Londell McMillan',
#  'Jagger',
#  'Retail Therapy',
#  'Adam Levine Denies Affair',
#  'Fran Drescher',
#  'Tyla Makes',
#  'Lisa Frankenstein',
#  'Aespa Are Getting',
#  "Warren Haynes'",
#  'Bang Si-Hyuk',
#  'Sam Bankman-Fried',
#  'Martinez',
#  "Niall Horan's",
#  'Monica',
#  "Metallica Rock '",
#  'Jon Batiste Wants You',
#  'Patti LaBelle',
#  'Kamala Harris Walks',
#  "Liam Payne's",
#  'Louis Tomlinson',
#  "Danny Elfman's '",
#  "Yeezy Porn'",
#  'Describes Rapper',
#  'Rob Thomas Thinks',
#  'Schoolboy Q Previews',
#  'Sophia Nahli',
#  'Minogue',
#  'Soundtrack Box Set',
#  'Ciara Taps',
#  'Elton John Join',
#  'Dogg Joins',
#  'Jorja Smith',
#  'Tokischa',
#  'Pink Pantheress',
#  'Manowar',
#  'Tom Petty Estate',
#  'Saint Levant',
#  'Sean Ono Lennon Defends',
#  'Jam Master',
#  'Sigur Rós Return',
#  'Goldblum',
#  'Tommy Lee Lawsuit',
#  'Kendrick Lamar Drops',
#  'Irv Gotti',
#  'Taylor Swift Is Officially Cheer Captain',
#  'Shakira Settles',
#  'Johnny Depp',
#  'Halsey Shares',
#  'U Was',
#  'Harry',
#  'Adam Levine Returning',
#  'Navigating Harmony',
#  'Timbaland Sue Triller',
#  'Luke Bryan',
#  'Workplace Allegations',
#  "Lainey Wilson Perform Anthemic Single '",
#  'Bill Pitman',
#  'Rob Cavallo',
#  'Gloss Up',
#  'Twitch',
#  'Miranda Lambert',
#  'Blink-182 Add',
#  'Split',
#  'Pens Op-Ed',
#  'Eddie Munson Costume',
#  'Vance Joy Celebrates Summer',
#  'Robert “Mack” McCormick',
#  'Til Dawn',
#  'Amy Poehler',
#  'Taylor Swift Takes',
#  'John McVie',
#  'Ryan Seacrest',
#  'Vicky Cornell',
#  'Frankie Beverly',
#  'KOOL',
#  "Jeff Buckley's",
#  'Serenade Brian Wilson',
#  'Nomad',
#  'Buzzcut',
#  'Hanukkah',
#  "Covid Concerns Poses '",
#  'Eddie Munson',
#  'Lizzo Says',
#  "David Gilmour Play '",
#  'Lady Gaga Posts',
#  'Kelly Clarkson Covers',
#  "Til Dawn'",
#  'Beach Bunny Wrap Up',
#  'Corgan',
#  'Bloodline Maintenance',
#  'Concert Lineup',
#  'Luke Bryan Announce',
#  'Tour Dates',
#  'Dre Reunite',
#  'Yankovic',
#  'Greasy Frybread',
#  'Bryan Freedman',
#  'Mary Weiss',
#  'Mary J. Blige Re-Joins',
#  'Andrew Dominik',
#  'Isaac Hayes Estate',
#  'Agnetha Faltskog',
#  'British Slang:',
#  'Daughter Aimee',
#  'Reindeerare',
#  'Benjamin',
#  'Steve Earle',
#  "Sinead O'Connor",
#  'Les Binks',
#  'David Bowie Reflects',
#  'West',
#  'Pearl Jam Reach',
#  'Daniel',
#  'Muna Make',
#  'Rivers Cuomo',
#  'Paul Vogel',
#  "C’est Comme Ça'",
#  'Femi Kuti',
#  'Postponing Launch',
#  'Solo Artist',
#  "Travis Kelce Bring Their '",
#  "Bill Lee'",
#  "Taylor Jenkins Reid's",
#  "Sabrina Carpenter '",
#  "Tame Impala's",
#  'Michael Douglas',
#  'Till Lindemann',
#  'Governors Ball',
#  'Howe',
#  'Billy Corgan Will',
#  'Jesse Jo Stark',
#  "Brenda Lee Perform '",
#  'Beyoncé',
#  'Remi Wolf Vibes',
#  'Stephen Colbert',
#  'Diana Ross Perform',
#  'Lisa Brings',
#  "Euphoric Gentlemen's",
#  'Flo Milli',
#  'Sean Combs',
#  'Barbara Maier',
#  'Kim Deal Delivers',
#  'Hindsin',
#  "Mac Miller's '",
#  "Dolly Parton's '",
#  'Rauw',
#  "Brandon Blackstock's",
#  'Morrison',
#  'Charlieonnafriday',
#  "Jonny Greenwood Becomes '",
#  'Death Revealed',
#  'James Murphy',
#  'Joe Rogan Talk Porn',
#  'James Blake',
#  'Hearts Clubahead',
#  'Tony Hinchcliffe’s',
#  "Ted Nugent's",
#  'Stonehas',
#  'Lizzo Accusers Fight',
#  'Daniel Seavey Mourns',
#  'Britney Spears',
#  'Beabadoobee Explores Japan',
#  'Mikaela Straus',
#  "Will Release '",
#  'Peter Jackson',
#  "Lil Yachty Takes '",
#  'Schuman',
#  'Teases Willie Nelson',
#  'Taylor Swift Reflects',
#  'Mark Knopfler',
#  'Baby Shark',
#  'Tommy Clufetos',
#  'Superpower',
#  'Mötley Crüe Confused',
#  'Joanna',
#  'Larry David',
#  'Singer-Songwriter',
#  "J. Cole Felt 'Conflicted'",
#  'Kylie Minogue Recruits Bebe Rexha',
#  "Lemmy Kilmister's",
#  'Jewel',
#  'Geddy Lee',
#  "Ya Ya'",
#  'Taylor Swift Won Travis Kelce',
#  'Israel Boycott',
#  'Lady Gaga Channels Harley Quinn',
#  'Opens Up About Anxiety Over People Discussing Weight',
#  'Debbie Harry to Collaborate',
#  'AP Rocky Wonders How to',
#  "Tiny Desk' Debut",
#  "Becky G's '",
#  'Vybz Kartel',
#  'Shakira Ordered',
#  'Xtina',
#  'Skittles',
#  'Terry Kirkman',
#  'Lauren Jauregui',
#  "Def Leppard's",
#  'Brianna Chickenfry',
#  'Olly Alexander',
#  'Chlöe Bailey',
#  'Eric Clapton Artifacts',
#  'Lukas Nelson',
#  'Bob Dylan biopicA Complete',
#  'Jung Kook Named',
#  'Fantasia Reflects',
#  'Nicky',
#  "Waxahatchee Revisit '",
#  "Judee Sill's",
#  "Faye Webster Releases '",
#  'Adele Return',
#  'Conan Gray Will',
#  "Elyanna Plots '",
#  'Miles',
#  'Tim Commerford Battling',
#  'Etty Liu Farrell',
#  'Herman Wallace',
#  "Sinéad O'Connor Was '",
#  'Bobby Brown',
#  'Gracie Abrams',
#  'Umi',
#  'Impala',
#  "Dua Lipa Continues '",
#  'Elton John’s ‘Tammy Faye’',
#  'Harry Styles Injured',
#  'Kecalf Franklin',
#  'Ann',
#  "Eddie Vedder Duet '",
#  'Guitar',
#  'Appearance Due',
#  'Marilyn Manson Accuser Recants Allegation',
#  "Michelle Williams '",
#  'Gus',
#  'Jay Park',
#  'Kristen Stewart-Directed Short Film',
#  'Shows Due',
#  'Taylor Swift Surprises',
#  "Kim Petras Celebrates Community Amidst '",
#  'Headline Outloud',
#  'David Dalton',
#  "Grateful Dead's '",
#  "Del Rey's '",
#  'Emma Stone Slaps',
#  'Lisa Revs Up',
#  'Herman',
#  'Nipsey',
#  'Ben Atkind',
#  'Runner',
#  'Rae Sremmurd',
#  'Kelly Clarkson Helps',
#  "Depeche Mode's",
#  "James Taylor Revisit '",
#  'Derrel McDavid',
#  'Solo Set',
#  'Jimmie Allen Apologizes',
#  'Junio',
#  'Taylor Swift Pulls',
#  'Ronnie Hawkins',
#  'Laufey Takes',
#  'Ben Gibbard’s',
#  'Gloria Gaynor',
#  'Halsey Puts',
#  'Lavigne Falls Apart',
#  'John Squire',
#  "Lou Reed's '",
#  'Philippines Concert',
#  'Alicia Keys Perform ‘Empire State of Mind',
#  'AP Ferg',
#  'Cardi B Teases New Music',
#  'Dolla',
#  'Gang Starr',
#  'Julianne Moore Set',
#  'Valerie',
#  'Ethel Cain Perform ‘Morning Elvis',
#  "Murda Beatz's",
#  'Andrew Wyatt',
#  'Lady Gaga Drops Stripped-Back',
#  'Diplo',
#  'Chuck Taylors',
#  'Paul McCartney Invites Bruce Springsteen',
#  'Raincoats',
#  'Hill',
#  'Daisy Jones',
#  'Michelle',
#  'Trial Continues',
#  'Shaun Ryder',
#  "Patrick Carney '",
#  'Iris Apatow',
#  'Renee Rapp Changed Directions',
#  'Standout',
#  'Larry Stylinson',
#  'Taylor Swift Called',
#  'Justin Johnson',
#  'Kesha Strips Down',
#  'Jennifer Lopez Celebrates',
#  'Zayn',
#  'Khan',
#  'Domino Kirke',
#  'Bill Wyman',
#  'Bob Bryar',
#  'Elvis Act Signed',
#  'Lorde Joins Muna',
#  'Taylor Swift Surprises Liverpool Show',
#  'Electrical Audio',
#  'Charlie Watts Biography',
#  'Civic Cipher',
#  "Sharon Stone's",
#  'Tommy Lee Accused',
#  'James Bond Film',
#  'Sevak Amroyan',
#  'Sampha Bites',
#  "Lisa Marie's Memorial",
#  ...}

# %%
news
# Out:
#                                                   title  \
# 0     Taylor Swift Awards Eras Tour Crew With $197 M...
# 1     Miley Cyrus Celebrates Golden Globe Nomination...
# 2     Gracie Abrams Announces U.S. ‘Secret of Us Del...
# 3     Azealia Banks Demands Apology and $1 Million F...
# 4     Liam Payne’s Girlfriend Kate Cassidy Shares Jo...
# ...                                                 ...
# 1005  Sylvan Esso Straddle Line Between Pleasure and...
# 1006  Seventeen Plot North American ‘[Be the Sun]’ Tour
# 1007  Pearl Jam Cancel Final U.S. Tour Dates After J...
# 1008  Elton John to Get the Official Documentary Tre...
# 1009  Interpol Conjure Up a 'Summer Jam' With New So...
#
#                                                    link  \
# 0     https://www.rollingstone.com/music/music-news/...
# 1     https://www.rollingstone.com/music/music-news/...
# 2     https://www.rollingstone.com/music/music-news/...
# 3     https://www.rollingstone.com/music/music-news/...
# 4     https://www.rollingstone.com/music/music-news/...
# ...                                                 ...
# 1005  https://www.rollingstone.com/music/music-news/...
# 1006  https://www.rollingstone.com/music/music-news/...
# 1007  https://www.rollingstone.com/music/music-news/...
# 1008  https://www.rollingstone.com/music/music-news/...
# 1009  https://www.rollingstone.com/music/music-news/...
#
#                                                 summary category  \
# 0     The Eras Tour also earned more than $2 billion...      NaN
# 1     The record, which appears in the Pamela Anders...      NaN
# 2     Following the singer's Eras Tour opening run, ...      NaN
# 3     Last week, Banks said she would be taking lega...      NaN
# 4     Cassidy previously paid homage to Payne in an ...      NaN
# ...                                                 ...      ...
# 1005  Electronic pop duo drop first new music since ...    Music
# 1006  K-pop group’s 12-date trek launches in support...    Music
# 1007  "Our attention to staying inside the bubble ha...    Music
# 1008  Film will be centered around the musician's on...    Music
# 1009  New LPThe Other Side of Make-Believearrives Ju...    Music
#
#                      extracted_names_title extracted_names_summary  \
# 0      [Taylor Swift Awards Eras, Bonuses]                      []
# 1                                  [Miley]   [Pamela Anderson-led]
# 2                          [Gracie Abrams]                      []
# 3                            [Matty Healy]                 [Banks]
# 4                           [Liam Payne’s]                      []
# ...                                    ...                     ...
# 1005           [Sylvan Esso Straddle Line]                      []
# 1006                                    []                      []
# 1007  [Pearl Jam Cancel Final, Jeff Ament]                      []
# 1008                          [Elton John]                      []
# 1009                                    []                      []
#
#                            extracted_names
# 0      [Bonuses, Taylor Swift Awards Eras]
# 1             [Pamela Anderson-led, Miley]
# 2                          [Gracie Abrams]
# 3                     [Matty Healy, Banks]
# 4                           [Liam Payne’s]
# ...                                    ...
# 1005           [Sylvan Esso Straddle Line]
# 1006                                    []
# 1007  [Jeff Ament, Pearl Jam Cancel Final]
# 1008                          [Elton John]
# 1009                                    []
#
# [10097 rows x 7 columns]
